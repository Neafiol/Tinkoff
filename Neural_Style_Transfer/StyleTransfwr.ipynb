# %%
# %matplotlib inline

# %% [markdown]
# Основные принципы
# --------------------
# 1. Принимаем на вход 3 картинки - content_image, style_image, input_image;
#
# <img src="https://pytorch.org/tutorials/_images/neuralstyle.png">
#
# 2. Вводим два расстояния:
#     - $D_C$ - [distance content] измеряет насколько близки по контенту 2 картинки
#     - $D_S$ - [distance style] измеряет насколько близки по стилю 2 картинки
#     - Для картинки input_image минимизируем расстояния $D_C$, $D_S$ до content_image, style_image соответственно

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
import torchvision.models as models

import copy

# %% [markdown]
# Ставим девайс

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !wget http://picasso-picasso.ru/wp-content/uploads/127.jpg -O style.jpg
# !wget https://pp.userapi.com/c846120/v846120483/14eb8e/33Z0XIa5VJ0.jpg -O photo.jpg
# Out:
# --2019-03-01 13:15:31--  http://picasso-picasso.ru/wp-content/uploads/127.jpg
# Resolving picasso-picasso.ru (picasso-picasso.ru)... 185.58.207.170
# Connecting to picasso-picasso.ru (picasso-picasso.ru)|185.58.207.170|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303814 (297K) [image/jpeg]
# Saving to: ‘style.jpg’
#
# style.jpg           100%[===================>] 296.69K   206KB/s    in 1.4s
#
# 2019-03-01 13:15:34 (206 KB/s) - ‘style.jpg’ saved [303814/303814]
#
# --2019-03-01 13:15:34--  https://pp.userapi.com/c846120/v846120483/14eb8e/33Z0XIa5VJ0.jpg
# Resolving pp.userapi.com (pp.userapi.com)... 87.240.182.234, 87.240.137.137, 87.240.137.139, ...
# Connecting to pp.userapi.com (pp.userapi.com)|87.240.182.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140918 (138K) [image/jpeg]
# Saving to: ‘photo.jpg’
#
# photo.jpg           100%[===================>] 137.62K   268KB/s    in 0.5s
#
# 2019-03-01 13:15:37 (268 KB/s) - ‘photo.jpg’ saved [140918/140918]

# %%
ls
# Out:
# photo.jpg  sample_data/  style.jpg

# %%
# уменьшаем картинки
from PIL import ImageOps
#обрежим фото

imsize = 512 if torch.cuda.is_available() else 256

loader = transforms.Compose([
    transforms.Resize(imsize), # уменьшаем картинку
    transforms.ToTensor()])  # делаем из картинки тензор


def image_loader(image_name):
    image = Image.open(image_name)
    ms=min(image.size)
    border = (0, 0, image.size[0]-ms, image.size[1]-ms) # left, up, right, bottom
    image=ImageOps.crop(image, border)
    # создаем фейковый дименшн для батча
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)

style_img = image_loader("./style.jpg")
content_img = image_loader("./photo.jpg")

assert(style_img.size() == content_img.size(),"Картинки для стиля и для контента должны быть одного размера")
# Out:
# <ipython-input-7-8ecdd4012be7>:23: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(style_img.size() == content_img.size(),"Картинки для стиля и для контента должны быть одного размера")

# %% [markdown]
# Конвертируем картинку обратно из тензора в формат `PIL` и показываем ее с помощью `plt.imshow()`

# %%
unloader = transforms.ToPILImage()  # конвертируем в `PIL image`

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  
    image = image.squeeze(0)      # убираем лишнюю размерность батча
    image = unloader(image)
    plt.imshow(image)
    plt.ioff()
    plt.grid(color='w', linestyle='-', linewidth=0)
    if title is not None:
        plt.title(title)
    plt.show()
#     plt.pause(0.001)


plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %% [markdown]
# Loss Functions
# --------------
# ### Content Loss

# %% [markdown]
# * Принимаем на вход фичи из прошлого сверточного слоя для content_image - $F_{CL}$ и то же самое для input_image - $F_{XL}$. Считаем расстояние между ними и называем это $D_C^L(X,C) = \|F_{XL} - F_{CL}\|^2$.
# * Расстояние считаем с помощью ``nn.MSELoss``.
# * Реализуем все это дело как модуль. Само расстояние $D_C^L(X,C)$ будет в нем хранится как параметр.

# %%
class ContentLoss(nn.Module):

    def __init__(self, target,):
        super(ContentLoss, self).__init__()
        # detach() используется, чтобы не считать градиенты до target
        self.target = target.detach()

    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input

# %% [markdown]
# ### Style Loss

# %% [markdown]
# * Берем матрицу $F_{XL}$, размерностью $[a,b,c,d]$, делаем размерность $[a\cdot b, c \cdot d]$
# * Считаем матрицу Грама $G_{XL}$ для этой матрицы: это перемножение матрицы на свою транспонированную копию.
# * Нормализуем матрицу Грама: делим каждое ее значение на полное количество элементов в матрице. Это необходимо сделать, чтобы операция получения матрицы Грама не повлияла на повышение активации нейронов.

# %%
def gram_matrix(input):
    a, b, c, d = input.size()  # a=batch size(=1)
    # b=number of feature maps
    # (c,d)=dimensions of a f. map (N=c*d)

    features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL

    G = torch.mm(features, features.t())  # compute the gram product

    # we 'normalize' the values of the gram matrix
    # by dividing by the number of element in each feature maps.
    return G.div(a * b * c * d)

# %% [markdown]
# Модуль для `StyleLoss` выглядит также, как модуль для `ContentLoss`,
#
# с той разницей, что теперь MSE считается для двух матриц Грама $\|G_{XL}$ - $G_{SL}\|^2$, а не для активаций слоев непосредственно.

# %%
class StyleLoss(nn.Module):

    def __init__(self, target_feature):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %%
class PixelLoss(nn.Module):

    def __init__(self, target_feature):
        super().__init__()
        self.target = target_feature.detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %% [markdown]
# Используем предобученную модель
# -------------------
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*Fe6z8VdUS6laTd6Ev3EohQ.gif">
#
# Импортируем наш любимый vgg, на этот раз vgg19 и ставим его в `eval()` мод, т.к. некоторые слои работают по-разному в режимах предсказания и обучения.
#
# В оригинальной статье использовали vgg19, но также возможно использование vgg16, но нужно подобрать параметры.

# %%
cnn = models.vgg19(pretrained=True).features.to(device).eval()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.torch/models/vgg19-dcbb9e9d.pth
# 574673361it [00:08, 64045481.67it/s]

# %% [markdown]
# Как и в прошлой части занятия, используем mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225] т.к. оригинальная VGG обучалась с такими параметрами препроцессинга для входных данных.

# %%
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)

# Делаем модуль для нормализации, чтобы потом без труда стакать в слои
# nn.Sequential
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        # .view the mean and std to make them [C x 1 x 1] so that they can
        # directly work with image Tensor of shape [B x C x H x W].
        # B is batch size. C is number of channels. H is height and W is width.
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        return (img - self.mean) / self.std

# %% [markdown]
# Мы создаем новый `Sequential` модуль содержащий те же модули, что и `vgg19.features`, только мы добавляем наши лоссы после каждого сверточного слоя, который мы хотим использовать.

# %%
# Какие именно слои мы хотим использовать чтобы считать наши лоссы
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    cnn = copy.deepcopy(cnn)

    # помним, что сначала нормализуем картинки
    normalization = Normalization(normalization_mean, normalization_std).to(device)

    # хотим иметь iterable с вставленными модулями
    content_losses = []
    style_losses = []

    # создаем свою модельку, в которую вставим лоссы
    model = nn.Sequential(normalization)

    i = 0  # increment every time we see a conv
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ContentLoss
            # and StyleLoss we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)

        if name in content_layers:
            # добавляем content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # добавляем style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # Обрезаем все слои, которые находятся после последнего ContentLoss или StyleLoss
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

# %% [markdown]
# Чаще всего в качестве `input_image` используется та же картинка что и `content_image`. Но также можно использовать и шумную картинку и посмотреть что получится тогда.

# %%
input_img = content_img.clone()

# Если есть желание подать шум, попробуйте эту строчку раскомментить
# input_img = torch.randn(content_img.data.size(), device=device)

plt.figure()
imshow(input_img, title='Input Image')

# %% [markdown]
# Gradient Descent
# ----------------
#
# Оптимизируем `input_image` используя `L-BFGS` оптимизатор, как советует автор оригинальной статьи вот [здесь](https://discuss.pytorch.org/t/pytorch-tutorial-for-neural-transfert-of-artistic-style/336/20?u=alexis-jacq).

# %%
def get_input_optimizer(input_img):
    # input_img - это параметры, до которых доходит градиент
    optimizer = optim.LBFGS([input_img.requires_grad_()])
    return optimizer

# %% [markdown]
# # Finally
#
#
# * Итеративно меняем `input_image`; для того параметр `num_steps`;
# * Можно менять веса для веса стиля и веса контента `style_weight`, `content_weight`;
# * Корректируем значения картинки так, чтобы они не выходили за пределы `[0..1]`
# * В функции `closure` мы собираем весь лосс из всех модулей, считаем градиенты.
# * Затем обновляем параметры модели с помощью `optimizer.step(closure)`

# %%
# from tqdm import tqdm
def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=320,
                       style_weight=1000000, content_weight=1):
    """ Поехали! """
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn, normalization_mean,
                                                                     normalization_std,
                                                                     style_img, content_img)
#     print(model.children)
    optimizer = get_input_optimizer(input_img)

    print('Optimizing..')
    run = [0]
    while num_steps>=run[0]:

        def closure():
            # корректируем значения, чтобы они лежали в пределах `[0..1]`
            input_img.data.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss

            style_score *= style_weight
            content_score *= content_weight

            loss = style_score + content_score
            loss.backward()

            run[0] += 1
            if run[0] % 50 == 0:
                print("run {}:".format(run))
                print('Style Loss : {:4f} Content Loss: {:4f}'.format(
                    style_score.item(), content_score.item()))
                print()

            return style_score + content_score

        optimizer.step(closure)

    # корректируем значения, чтобы они лежали в пределах `[0..1]` для финальной картинки
    input_img.data.clamp_(0, 1)

    return input_img

# %% [markdown]
# Запускаем!

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img,style_weight=1000000,num_steps=150)

plt.figure()
imshow(output, title='Output Image')
imshow(style_img, title='Style Image')
imshow(content_img, title='Result Image')
plt.ioff()
plt.grid(linewidth=0)
plt.show()
# Out:
# Building the style transfer model..
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# Optimizing..
# run [50]:
# Style Loss : 633.656494 Content Loss: 42.935219
#
# run [100]:
# Style Loss : 201.359192 Content Loss: 45.730450
#
# run [150]:
# Style Loss : 89.404816 Content Loss: 47.319614

# %%
plt.figure()
plt.ioff()

imshow(output, title='Output Image')
imshow(style_img, title='Style Image')
imshow(content_img, title='Result Image')

# plt.grid(linewidth=0)
# plt.show()
